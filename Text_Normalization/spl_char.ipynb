# %% [markdown]
# if not char.isalnum() or not ord(char)==32:

# %%
with open("data.txt","r") as file:
    data=file.read()
    for char in data:
        if not char.isalnum() and not ord(char)==32: # expect this remove 
            data=data.replace(char,"")
            # print(data)
            # print()
print(data)
# Out:
# python is a            amzing languagepython  is object oriented high level interpreted scrpting language as well as programming lanuguagepyhton is vry easy       to read nd writepython has         very easy syntax
