# %%
import nltk
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("wordnet")
nltk.download("averaged_perceptron_tagger_eng")
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\ASUS\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tokens = ['running', 'ran', 'runs', 'children', 'geese', 'better', 'wolves', 'a','cars', 'happier', 'studies']

# %%
lemmatize=WordNetLemmatizer()

# %%
for word in tokens:
    print(word,lemmatize.lemmatize(word,pos='v'))
#it acceptstwoparametrs:
#-->word->>converts to root form
#--> part of speech:  default n(str)
# Out:
# running run
# ran run
# runs run
# children children
# geese geese
# better better
# wolves wolves
# a a
# cars cars
# happier happier
# studies study

# %% [markdown]
# - This is not removing all the suffic
# - if the word noun it applies lemmatization, beacuse  it accepts parts of speech
# - disadvantages:

# %%
nltk.pos_tag(['running'])
# Out:
# [('running', 'VBG')]

# %%
nltk.pos_tag(tokens)

'''


pos : str
The Part Of Speech tag. Valid options are "n" for nouns, "v" for verbs, "a" for adjectives, "r" for adverbs and "s" for satellite adjectives.

start from
JJ          --> Adjective


except this


'''
# Out:
# '\n\n\npos : str\nThe Part Of Speech tag. Valid options are "n" for nouns, "v" for verbs, "a" for adjectives, "r" for adverbs and "s" for satellite adjectives.\n\nstart from\nJJ          --> Adjective\n\n\nexcept this\n\n\n'

# %% [markdown]
# 18.46:

# %%
def find_postag(tag):
    if tag.startswith('J'):
        return 'a'
    elif tag.startswith('N'):
        return 'n'
    elif tag.startswith('V'):
        return 'v'
    elif tag.startswith('R'):
        return r
    else:
        return 'n'

# %% [markdown]
# | Word | Tag | Meaning                            |
# | ---- | --- | ---------------------------------- |
# | John | NNP | Proper Noun (person's name)        |
# | 's   | POS | Possessive ending                  |
# | big  | JJ  | Adjective                          |
# | idea | NN  | Noun (singular)                    |
# | is   | VBZ | Verb (3rd person singular present) |
# | n't  | RB  | Adverb (negation)                  |
# | all  | PDT | Predeterminer                      |
# | that | DT  | Determiner                         |
# | bad  | JJ  | Adjective                          |
# | .    | .   | Punctuation                        |

# %%
def lemmatize_tokens(tokens_list):
    def get_wordnet_pos(treebank_tag):
        if treebank_tag.startswith("J"):
            return "a"
        if treebank_tag.startswith("V"):
            return "v"
        if treebank_tag.startswith("N"):
            return "n"
        if treebank_tag.startswith("R"):
            return "r"
        return "n"

    tagged = nltk.pos_tag(tokens_list)
    return [lemmatize.lemmatize(word, pos=get_wordnet_pos(tag)) for word, tag in tagged]

# %% [markdown]
# TASKS: with this funcc, just update all these words, updated lematization words include all parts of speech (hint:dict.items)

# %%
pos_tag_words=nltk.pos_tag_words
pos_tag_words
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 pos_tag_words=nltk.pos_tag_words
#       2 pos_tag_words
#
# AttributeError: module 'nltk' has no attribute 'pos_tag_words'

# %%
for word, tag in pos_tag_words:
    print(word,find_postag(tag))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 for word, tag in pos_tag_words:
#       2     print(word,find_postag(tag))
#
# ValueError: too many values to unpack (expected 2)

# %%
for word, tag in pos_tag_words:##(houses,MMC),--------> goes to def....above
    tagged_word=lemmatizer.lemmatize(word,find_postag(tag))
    #lemmatizer.lemmatize('houses','n)
    print(tagged_word)

# %% [markdown]
# drawback: manually we have to find postag, and convert it to root form,
# here we require potag,
