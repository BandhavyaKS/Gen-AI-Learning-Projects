# %%
import pandas as pd

# %%
with open("data.txt", "r+") as file:
    data = file.read().lower()# bcs raead method returns string, we can acess lower directly

    file.seek(0)
    file.write(data)
   

print(data)
# Out:
# p$#1. python is a simple, powerful,  &*(and easy-to-learn p*() rogramming language.
#    python has a clear syntax,   %^&*making code readable, maintainable, and efficient.
# %^&*&p,it is widely used in wepw#$b development, data science, machine learning, and automation.^^&(*(f,d--p.
# wddits rich libraries and strong communiwbdp,dcc,c,d.ty support help developers build applications quickly.p%^*cx,kcddb,b,dffc.
