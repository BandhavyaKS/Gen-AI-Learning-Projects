# %% [markdown]
# if not char.isalnum() or not ord(char)==32:

# %%
with open("data.txt","r+") as file:
    data=file.read()
    for char in data:
        if not char.isalnum() and not ord(char)==32: # expect this remove 
            
            data=data.replace(char,"") 
            # replace returns the new string , so write it and store it in data
            # why assign back to the data?
                #  becz string is immutable, cannot modify the original string
    file.seek(0)
    file.write(0)
            # print(data)
            # print()
print(data)
# Out:
# Python is an amazing languagepythin has easy syntax
