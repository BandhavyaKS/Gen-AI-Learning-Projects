# %%
x="i am     bandhavya"
x.split()
" ".join(x.split())
# Out:
# 'i am bandhavya'

# %%
with open('data.txt','r+') as file:
    data=file.read()
    words=data.split()
    data=" ".join(data)
    file.seek(0)
    file.write()
print(data)

# %%
print(data)
# Out:
# Python is an amazing language pythin has easy syntax
