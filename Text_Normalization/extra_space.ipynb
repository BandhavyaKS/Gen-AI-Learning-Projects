# %%
x="i am     bandhavya"
x.split()
" ".join(x.split())
# Out:
# 'i am bandhavya'

# %% [markdown]
# here we cant remove spaces because it checks characeter by character

# %%
with open("data.txt","r") as file:
    data=file.read()
    for char in data:
        if not char.isalnum() and not ord(char)==32: # expect this remove 
            data=data.replace(char,"")
            # print(data)
            # print()
print(data)
# Out:
# python is a            amzing languagepython  is object oriented high level interpreted scrpting language as well as programming lanuguagepyhton is vry easy       to read nd writepython has         very easy syntax

# %%
with open('data.txt','r') as file:
    data=file.read()
    words=data.split()
    data=" ".join(data.split())

# %%
print(data)
# Out:
# py&*thon is a amzi:@ng lang":uage python is object# oriented high level interpr'eted scrpting l,anguage as well as pr,ogramming la,nuguage pyhton is vry easy to& read nd write pytho$$n has very easy syntax*&

# %%
s="open file"
