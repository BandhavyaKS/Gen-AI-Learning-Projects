# %% [markdown]
# we want  create seperate module, so that we can run anywhere

# %%
import string

# %%
result=string.punctuation
print(result)
print(len(string.punctuation))
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# 32

# %%
import string
s = string.punctuation
data = "Python is !!@ very @ ama%zing language&*()"
result = ""
for i in data:
    if i not in s:
        result += i
print(result)
# Out:
# Python is  very  amazing language

# %%
with open('data.txt','r') as file:
    data = file.read()
    for char in data:
        if char in result:
            data = data.replace(char,'')
# print(data)
with open('data.txt','w') as file:
    file.write(data)
print(data)
# Out:
# p$#1.pp,pwf,&*(d--p*().
# pcx,%^&*kcddb,b,dffc.
# %^&*&p,wddwpw#$bdp,dcc,c,d.^^&(*(f,d--p.
# wddcbdcwbdp,dcc,c,d.pppdpbdppcqck.p%^*cx,kcddb,b,dffc.
