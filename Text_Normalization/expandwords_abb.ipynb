# %%
# pip install contractions

# %%
import contractions

# %%
s1="I'm not okay"
s2="btw  ASAP I'll try to complete my task"
# contractions.fix(s1)
contractions.fix(s2)
# Out:
# 'by the way  AS SOON AS POSSIBLE I will try to complete my task'

# %%
with open("1_data.txt","r+")as file:
    data=file.read()
    data=contractions.fix(data)
        
    file.seek(0)
    file.write(data)
print(data)
# Out:
# Python is amazing lanuage
# python has easy syntax
# by the way, AS SOON AS POSSIBLE I will try to complete my task
