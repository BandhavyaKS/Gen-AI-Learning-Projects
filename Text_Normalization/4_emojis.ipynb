# %%
# pip install emoji
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import emoji

# %%
s="helooooo😂👌😁hiii"
emoji.replace_emoji(s,"")
# Out:
# 'helooooohiii'

# %%
s="helooooo😂👌😕😁hiii"
emoji.demojize(s)


## this can be used for sentimental analysis
# Out:
# 'helooooo:face_with_tears_of_joy::OK_hand::confused_face::beaming_face_with_smiling_eyes:hiii'
