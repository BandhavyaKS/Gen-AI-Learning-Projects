# %% [markdown]
# ## **Fixed Size-Overlapping**

# %% [markdown]
# - It is used in RAG
# - It hleps to preserve the word
# - overlapping should be 50%-20% of fixed size

# %%
with open("1data.txt", "r") as file:
    data = file.read()

    chunks = []
    n = 20
    overlap=6

    for char in range(0, len(data), n):
        chunk = data[char:overlap+char+n]
        print(chunk)
# Out:
# Regression is a supervised
# rvised machine learning te
# ing technique used to pred
# o predict continuous numer
#  numerical values. It lear
# t learns the relationship
# nship between input featur
# features and a numeric tar
# ic target variable using h
# sing historical labeled da
# led data. For example, a h
# e, a house price predictio
# diction model learns from
#  from past house data and
# a and predicts the price o
# rice of a new house based
# based on its features such
# s such as area and number
# umber of bedrooms.
