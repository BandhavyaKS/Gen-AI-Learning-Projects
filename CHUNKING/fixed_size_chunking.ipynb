# %%
with open("1data.txt","r+") as file:
    data=file.read()
chunks=[]
n=10
for char in range(0,len(data),n):
    chunks=data[char:char+n]
    file.seek(0)
    file.write(chunks)
print(chunks)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       3 chunks=[]
#       4 n=10
#       5 for char in range(0,len(data),n):
#       6     chunks=data[char:char+n]
# ----> 7     file.seek(0)
#       8     file.write(chunks)
#       9 print(chunks)
#      10
#
# ValueError: I/O operation on closed file.

# %%
with open("1data.txt", "r+") as file:
    data = file.read()

    chunks = []
    n = 10

    for char in range(0, len(data), n):
        chunk = data[char:char+n]
        print(chunk)

        file.seek(0)
        file.write(chunk)
        file.truncate()
# Out:
# Regression
#  is a supe
# rvised mac
# hine learn
# ing techni
# que used t
# o predict
# continuous
#  numerical
#  values. I
# t learns t
# he relatio
# nship betw
# een input
# features a
# nd a numer
# ic target
# variable u
# sing histo
# rical labe
# led data.
# For exampl
# e, a house
#  price pre
# diction mo
# del learns
#  from past
#  house dat
# a and pred
# icts the p
# rice of a
# new house
# based on i
# ts feature
# s such as
# area and n
# umber of b
# edrooms.
