# %% [markdown]
# ## **Paragraph based chunking**

# %% [markdown]
# - it divides into chunkes based on the '.',',''/n

# %%
with open("1data.txt", "r") as file:
    data = file.read()

paragraphs = data.split("\n\n")

for i, paragraph in enumerate(paragraphs, start=1):
    print(f"Chunk {i}:")
    print(paragraph)
    print("-" * 40)
# Out:
# Chunk 1:
# Regression is a supervised machine learning technique   used to predict continuous numerical values. It learns the relationship/n between input features and a numeric target variable /nusing historical labeled data. For example, a house price prediction model learns from past house data and predicts the price of a new house based on its features such as area and number of bedrooms.
# ----------------------------------------

# %%
with open("1data.txt", "r") as file:
    data = file.read()

chunks = data.split(". ")

for i in range(len(chunks)):
    print(f"Chunk {i+1}")
    print(chunks[i])
    print("-" * 40)
# Out:
# Chunk 1
# Regression is a supervised machine learning technique   used to predict continuous numerical values
# ----------------------------------------
# Chunk 2
# It learns the relationship/n between input features and a numeric target variable /nusing historical labeled data
# ----------------------------------------
# Chunk 3
# For example, a house price prediction model learns from past house data and predicts the price of a new house based on its features such as area and number of bedrooms.
# ----------------------------------------

# %%
pip install langchain
# Out:
# Collecting langchain
#   Using cached langchain-1.3.14-py3-none-any.whl.metadata (6.1 kB)
# Collecting langchain-core<2.0.0,>=1.4.9 (from langchain)
#   Using cached langchain_core-1.5.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting langgraph<1.3.0,>=1.2.5 (from langchain)
#   Using cached langgraph-1.2.9-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (2.13.4)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.4.9->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-protocol>=0.0.17 (from langchain-core<2.0.0,>=1.4.9->langchain)
#   Using cached langchain_protocol-0.0.18-py3-none-any.whl.metadata (2.4 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.4.9->langchain)
#   Downloading langsmith-0.10.10-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.4.9->langchain)
#   Downloading uuid_utils-0.17.0-cp314-cp314-win_amd64.whl.metadata (6.5 kB)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain)
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.5.0,>=0.4.2 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading langgraph_sdk-0.4.2-py3-none-any.whl.metadata (3.6 kB)
# Collecting xxhash>=3.5.0 (from langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading xxhash-3.8.1-cp314-cp314-win_amd64.whl.metadata (15 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading ormsgpack-1.12.2-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.28.1)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading orjson-3.11.9-cp314-cp314-win_amd64.whl.metadata (43 kB)
# Collecting websockets<16,>=14 (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain)
#   Downloading websockets-15.0.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: anyio>=3.5.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.9.0)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.33.1)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (1.3.1)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain)
#   Downloading zstandard-0.25.0-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: certifi in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain) (2.6.3)
# Downloading langchain-1.3.14-py3-none-any.whl (139 kB)
# Using cached langchain_core-1.5.0-py3-none-any.whl (558 kB)
# Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Downloading langgraph-1.2.9-py3-none-any.whl (247 kB)
# Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.4.2-py3-none-any.whl (160 kB)
# Downloading langsmith-0.10.10-py3-none-any.whl (675 kB)
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    ---------------------------------------- 0.0/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/675.2 kB ? eta -:--:--
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ------------------------------ -------- 524.3/675.2 kB 26.7 kB/s eta 0:00:06
#    ---------------------------------------- 675.2/675.2 kB 34.1 kB/s  0:00:23
# Using cached uuid_utils-0.17.0-cp314-cp314-win_amd64.whl (175 kB)
# Using cached websockets-15.0.1-py3-none-any.whl (169 kB)
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# Using cached langchain_protocol-0.0.18-py3-none-any.whl (7.2 kB)
# Downloading orjson-3.11.9-cp314-cp314-win_amd64.whl (127 kB)
# Downloading ormsgpack-1.12.2-cp314-cp314-win_amd64.whl (117 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Downloading xxhash-3.8.1-cp314-cp314-win_amd64.whl (33 kB)
# Downloading zstandard-0.25.0-cp314-cp314-win_amd64.whl (516 kB)
# Installing collected packages: zstandard, xxhash, websockets, uuid-utils, ormsgpack, orjson, langchain-protocol, jsonpointer, requests-toolbelt, jsonpatch, langsmith, langchain-core, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#
#    ----------------------------------------  0/17 [zstandard]
#    ----------------------------------------  0/17 [zstandard]
#   Attempting uninstall: websockets
#    ----------------------------------------  0/17 [zstandard]
#     Found existing installation: websockets 16.0
#    ----------------------------------------  0/17 [zstandard]
#    ---- -----------------------------------  2/17 [websockets]
#     Uninstalling websockets-16.0:
#    ---- -----------------------------------  2/17 [websockets]
#       Successfully uninstalled websockets-16.0
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    ---- -----------------------------------  2/17 [websockets]
#    --------- ------------------------------  4/17 [ormsgpack]
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\ASUS\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\ormsgpack\\__init__.py'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain_text_splitters
# Out:
# Collecting langchain_text_splitters
#   Downloading langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting langchain-core<2.0.0,>=1.2.31 (from langchain_text_splitters)
#   Using cached langchain_core-1.5.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.0.18)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters)
#   Using cached langsmith-0.10.10-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (26.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.1.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (4.13.0)
# Requirement already satisfied: distro>=1.7.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.33.1)
# Requirement already satisfied: sniffio>=1.1 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.3.1)
# Requirement already satisfied: websockets>=15.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.8.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.25.0)
# Requirement already satisfied: certifi in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (1.0.9)
# Requirement already satisfied: idna in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.13)
# Requirement already satisfied: h11>=0.16 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\ASUS\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_text_splitters) (2.6.3)
# Downloading langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Using cached langchain_core-1.5.0-py3-none-any.whl (558 kB)
# Using cached langsmith-0.10.10-py3-none-any.whl (675 kB)
# Installing collected packages: langsmith, langchain-core, langchain_text_splitters
#
#    ---------------------------------------- 0/3 [langsmith]
#
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'c:\\Users\\ASUS\\AppData\\Local\\Programs\\Python\\Python314\\Lib\\site-packages\\langsmith\\client.py'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 26.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
